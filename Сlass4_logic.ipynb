# %% [markdown]
# <a href="https://colab.research.google.com/github/lipchenko/lipchenko_HSE_student/blob/main/%D0%A1lass4_logic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
scores = 75
premium_user = False
result = (scores >= 60 ) or (premium_user == True)
print(result)
# Out:
# True

# %%
shopping = 6000
discount = False
result = shopping >= 5000 or discount
if result:
    sale = shopping * 0.9
print(result)
print(sale)
# Out:
# True
# 5400.0

# %%
import re
password = "secure123"
length = len(password)
numbers = any(char.isdigit() for char in password)
valid_password = (length >= 8) and numbers
print(valid_password)
# Out:
# True

# %%
score = 4.7
duty = False

money = score >= 4.5 and duty == True

print(money)
# Out:
# False

# %%
comment = "Отличный пост! Спасибо за информацию."
banned_words = ["спам", "реклама", "вирус"]
comment_lower = comment.lower()
length = len(comment_lower) <= 500
valid_words = all(banned_word not in comment_lower for banned_word in banned_words)
result = length and valid_words
print(result)
# Out:
# True

# %%
text = "Мне нужно срочно отправить письмо клиенту"

if "срочно" in text or len(text) > 50:
    print("high priority")
elif "?" in text:
    print("question")
else:
    print(len(text))
# Out:
# high priority

# %%
budget = "mid"
kitchen = "Italian"
Is_vegetarian = False

if budget == "low" and kitchen == "Italian":
    print("Пиццерия")
elif kitchen == "vegan":
    print("Вегетарианское кафе")
elif budget == "high":
    print("Рекомендуем премиум-ресторан")
else:
    print("Другие варианты")
# Out:
# Другие варианты

# %%
temperature_in_room = 22
prefer_temperature = 23
street = 15
user_in_home = True

if temperature_in_room < prefer_temperature and user_in_home:
    print("Включить отопление")
elif temperature_in_room > 30:
    print("Включить охлаждение")
elif user_in_home is False:
    print("Включить энергосбережение")
else:
    print("Поддерживать текущий режим")
# Out:
# Включить отопление

# %%
door_closed = True
window_closed = False
detected_move = True
is_night = True

if detected_move:
    print("Тревога!")
elif not window_closed and is_night:
    print("Предупреждение!")
elif door_closed and window_closed:
    print("Все в норме!")
else:
    print("Стандартный режим!")
# Out:
# Тревога!

# %%
traffic_jam = 8
distance = 25
last_time = 45
alt_route = True

if traffic_jam > 8 and alt_route:
    print("Искать объезд")
elif distance < 10:
    print(f"Показать оставшееся{last_time}")
elif traffic_jam > 5 and not alt_route:
    print("Есть пробки!")
else:
    print("Продолжаем маршрут")
### ваше решение здесь ###
# Out:
# Продолжаем маршрут

# %%
age = 20
subscribe = True

if age >= 18:
    if subscribe is True:
        print("Полный доступ")
    elif not subscribe:
        print("Только бесплатный контент")
elif age < 18:
    print("Доступ ограничен")
# Out:
# Полный доступ

# %%
order_delivered = True
status = "Завершен" if order_delivered else ("В обработке")
print(status)
# Out:
# Завершен

# %%
shopping = 6000
has_promo = True

discount = "скидка 15%" if shopping > 5000 and has_promo else ("скидка 5%")
print(discount)
# Out:
# скидка 15%

# %%
email = "user@example.com"

valid_email = "Валидный email" if "@" and "." in email else ("Невалидный email")
print(valid_email)
# Out:
# Валидный email
