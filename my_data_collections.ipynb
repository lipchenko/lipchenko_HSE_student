# %% [markdown]
# <a href="https://colab.research.google.com/github/lipchenko/lipchenko_HSE_student/blob/main/my_data_collections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Синтаксис

# %% [markdown]
# **Задача 1**
#
# Создайте список mixed_data, содержащий:
#
# - 3 числа (int)
# - 2 строки (str)
# - 1 вложенный список
# - 1 кортеж
# - 1 множество
#
# Добавьте в конец списка число 123
#
# Удалите вторую строку из списка
#
# Вставьте строку "inserted" на позицию 2
#
# Выведите итоговый список

# %%
mixed_data = [1, 2, 3, "blue", "white", [], (), {}]
mixed_data.append(123)
mixed_data.pop(4)
mixed_data.insert(2, "inserted")
print(mixed_data)
# Out:
# [1, 2, 'inserted', 3, 'blue', [], (), {}, 123]

# %% [markdown]
# **Задача 2**
#
# Создайте кортеж user_credentials, содержащий:
#
# - Логин (строка)
#
# - Хэш пароля (строка)
#
# - Уровень доступа (целое число)
#
# Попробуйте изменить уровень доступа (должна возникнуть ошибка)
#
# Напишите комментарий, почему кортеж подходит для хранения таких данных

# %%
user_credentials = ("ya_lublu_sirniki", "5f4dcc3b5aa765d61d8327deb882cf99", 2)
user_credentials[2] = 3
print(user_credentials)

#Комментарий: кортежи содержат неизменяемые данные, их невозможно отредактировать.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3713677837.py in <cell line: 0>()
#       1 user_credentials = ("ya_lublu_sirniki", "5f4dcc3b5aa765d61d8327deb882cf99", 2)
# ----> 2 user_credentials[2] = 3
#       3 print(user_credentials)
#       4
#       5 #Комментарий: кортежи содержат неизменяемые данные, их невозможно отредактировать.
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Задача 3**
#
# Дано:

# %%
tags1 = {"python", "ml", "data"}
tags2 = {"ml", "nlp", "deeplearning"}

# %% [markdown]
# Найдите:
#
# - Общие теги (пересечение)
#
# - Все уникальные теги (объединение)
#
# - Теги, которые есть в tags1, но нет в tags2

# %%
tag3 = tags1 & tags2
tag4 = tags1 | tags2
tag5 = tags1 - tags2
print(f"Пересечение: {tag3},"
      f" объединение:{tag4},"
      f" есть в tags1, но нет в tags2: {tag5}")
# Out:
# Пересечение: {'ml'}, объединение:{'nlp', 'deeplearning', 'ml', 'data', 'python'}, есть в tags1, но нет в tags2: {'data', 'python'}

# %% [markdown]
# ### Фильтрация и обработка текстовых данных

# %% [markdown]
# 1. Установите nltk и загрузите стоп-слова для русского и английского языков
#
# *Уже выполнено: просто запустите эту ячейку*

# %%
import nltk
import string
from nltk.corpus import stopwords

# Установка nltk и загрузка стоп-слов
nltk.download('stopwords')

# Загрузка стоп-слов для русского и английского языков
stopwords_english = stopwords.words('english')
stopwords_russian = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# 2. Конвертируйте списки слов на русском и английском, приведите их к виду множства `set`
#
# *Это стандартная операция: работа со стоп-словами всегда начинается с фильтрации, удаления дубликатов*

# %%
eng_stop = set(stopwords_english)
rus_stop = set(stopwords_russian)

# %% [markdown]
# 3. Выведите на экран первые 10 стоп-слов из двух списков
#
# *Подумайте, как это сделать, ведь `set` нельзя индексировать, а созданный список слов нельзя перезаписывать*

# %%
print("Английские стоп-слова (первые 10 слов):")

count = 0
for word in eng_stop:
    if count in range(10):
        print(word)
        count += 1

print("Русские стоп-слова (первые 10 слов):")

count = 0
for word in rus_stop:
    if count in range(10):
        print(word)
        count += 1
# Out:
# Английские стоп-слова (первые 10 слов):
# they'll
# he'll
# as
# needn't
# doing
# re
# no
# when
# mightn
# more
# Русские стоп-слова (первые 10 слов):
# много
# чуть
# какой
# чего
# ей
# по
# мой
# больше
# и
# есть

# %% [markdown]
# 4. Дан текст

# %%
# Исходный текст
text = """
This is a sample text for processing. It contains some stopwords and important words.
Этот текст содержит как английские, так и русские слова, включая стоп-слова.
"""

# %% [markdown]
# Допишите функцию в указанном плейсхолдере
#
# Функция:
#
# - удаляет знаки препинания
# - разбивает текст на слова
# - приводит текст к нижнему регистру

# %%
import re
# Токенизация текста на слова
def tokenize_text(text):
    words = re.findall(r'\b[\w-]+\b', text.lower())
    return words

# %% [markdown]
# Применим нашу функцию к тексту

# %%
# Токенизируем текст
words = tokenize_text(text)

# %% [markdown]
# Выведите на экран список токенов и общее количество слов

# %%
print(f"Все слова после токенизации: {words},\nВсего слов: {len(words)}")
# Out:
# Все слова после токенизации: ['this', 'is', 'a', 'sample', 'text', 'for', 'processing', 'it', 'contains', 'some', 'stopwords', 'and', 'important', 'words', 'этот', 'текст', 'содержит', 'как', 'английские', 'так', 'и', 'русские', 'слова', 'включая', 'стоп-слова'],
# Всего слов: 25

# %% [markdown]
# 5. Произведите фильтрацию стоп-слов для двух языков
#
# - Создайте пустой список
# - Запустите цикл for (`for word in words`, для каждого слова в списке слов)
# - Если слова нет в списке стоп-слов
# - Сделайте `append` в созданный список
#
# *Допишите функцию*

# %%
# Фильтрация стоп-слов для обоих языков
def filter_stopwords(words, stopwords_set):
    filtered_words = []
    for word in words:
        if word.lower() not in stopwords_set:
            filtered_words.append(word)
    return filtered_words

# %% [markdown]
# 6. Примените операции со множествами

# %%
# Объедините стоп-слова обоих языков в общее множество
common = eng_stop | rus_stop
print(common)
# Out:
# {"they'll", 'много', "he'll", 'чуть', 'какой', 'ей', 'when', 'по', 'no', 'mightn', 'мой', 'if', 'есть', 'haven', 'o', "they've", 'при', 'of', 'mustn', 'разве', 'who', 'ему', 'всего', 'сейчас', "she's", "aren't", 'yourself', 'том', 'to', "shan't", 'еще', 'раз', 'вы', "i'll", 'если', 'these', 'этого', 'совсем', 'не', 'by', 'со', "shouldn't", 'this', 'эти', 'нибудь', 'куда', 'were', 'll', 'с', 'in', 'вот', 'do', 'under', 'shouldn', 'has', 'у', 'further', "couldn't", 'про', 'doesn', "he's", "it's", 'your', 'not', "he'd", 'были', 'другой', 'whom', "didn't", 'the', 'same', 'более', 'or', 'зачем', 'него', 'below', 'then', "you'll", 'down', 'you', 'ourselves', 'нельзя', 'after', "she'll", "don't", 'myself', "you've", 'does', "won't", 'with', 'my', 'эту', 'что', 't', 'теперь', 'через', 'себя', "i'm", 'they', 'yourselves', 'к', 'никогда', "i'd", 'нас', 'три', 'уж', 'после', 'всю', 'against', 'быть', 'себе', "it'll", 'ней', "hadn't", 'than', 'themselves', 'во', 'за', 'each', 'о', 'his', 'won', 'during', 'вам', 'на', 'них', 'its', 'on', 'я', 'been', "they'd", "wasn't", 'конечно', 'having', 'how', 'было', 'уже', 'her', 'needn', 'хоть', 'под', 'может', 'иногда', 'i', 'же', 'ma', 'aren', 'его', 'перед', 'me', 'но', 'some', 'ну', 'she', 'own', 'had', 'about', "mightn't", 'тем', 'isn', 'off', 'before', 'наконец', 'тот', 'itself', 'up', 'для', "we'd", 'он', 'вас', 'as', 'чего', "needn't", 'doing', 're', 'more', 'don', 'больше', 'only', 'd', 'should', 'was', 'most', 'such', 'и', 'их', 'такой', 'до', 'for', 'is', 'чем', 'был', 'чтобы', 'тоже', 'два', 'этот', 'until', 'об', 'того', 'где', 'a', 'hadn', 'couldn', 'мы', 'а', 'ничего', 'herself', "you're", 'between', 'этой', 'была', 'вдруг', 'там', 'too', 've', 'тут', 'am', 'лучше', 'моя', 'меня', 'потом', 'чтоб', 'there', "should've", 'все', 'didn', "isn't", 'why', 'ни', "haven't", "they're", 'over', "you'd", 'то', 'nor', 'once', 'being', 'himself', "mustn't", 'впрочем', 'тебя', 'как', 'можно', 'now', 'свою', 'им', 'him', 'again', 'да', "we've", 'нее', 'what', 'так', 'will', "doesn't", 'ее', 'всех', 'будто', 'мне', 's', 'будет', 'потому', 'any', "wouldn't", 'от', 'here', 'хорошо', 'be', 'weren', 'надо', 'этом', 'those', 'have', "weren't", 'между', 'ним', 'здесь', 'so', 'theirs', 'but', 'ли', 'where', 'while', "that'll", 'ж', 'только', 'which', "it'd", 'из', 'yours', 'они', 'сам', "she'd", 'their', 'and', 'we', 'above', 'wasn', 'даже', 'through', 'wouldn', 'from', 'без', 'into', 'shan', 'few', 'hers', 'out', 'нет', 'at', 'an', 'it', 'бы', 'опять', 'did', 'hasn', 'very', 'один', 'тогда', 'just', 'are', 'ведь', 'ain', 'can', "hasn't", 'our', 'them', "i've", 'она', 'ты', 'that', 'всегда', 'ours', 'над', 'y', 'he', 'почти', 'в', 'all', 'm', "we're", 'или', "we'll", 'кто', 'когда', 'both', 'other', 'какая', 'because'}

# %% [markdown]
# 7. Применим нашу функцию для фильтрации данных
#
# *В переменной `all_stopwords` должен быть результат объединения множеств из пункта 6*

# %%
# Фильтруем стоп-слова
all_stopwords = common
meaningful_words = filter_stopwords(words, all_stopwords)

# %% [markdown]
# Выведите на экран список `meaningful_words`, а также длину этого списка

# %%
print(f"Слова после фильтрации стоп-слов: {meaningful_words},\nКоличество слов после фильтрации: {len(meaningful_words)}")
# Out:
# Слова после фильтрации стоп-слов: ['sample', 'text', 'processing', 'contains', 'stopwords', 'important', 'words', 'текст', 'содержит', 'английские', 'русские', 'слова', 'включая', 'стоп-слова'],
# Количество слов после фильтрации: 14

# %% [markdown]
# 8. Создаем множество уникальных значимых слов
#
# *Конвертируем список `meaningful_words` к виду множества*

# %%
mngfl_wds_st = set(meaningful_words)

# %% [markdown]
# Выведите на экран результат, а также длину полчившегося множества

# %%
mngfl_wds_st = set(meaningful_words)
print(f"Уникальные значимые слова:{mngfl_wds_st},\nКоличество уникальных значимых слов: {len(mngfl_wds_st)}")
# Out:
# Уникальные значимые слова:{'текст', 'words', 'stopwords', 'содержит', 'включая', 'sample', 'стоп-слова', 'слова', 'русские', 'important', 'contains', 'английские', 'processing', 'text'},
# Количество уникальных значимых слов: 14

# %% [markdown]
# 9. Создайте отчет
#
# - выведите исходное количество стоп-слов на английском
# - исходное количество слов на русском
# - общее количество стоп-слов

# %%
print(
    f"Всего стоп-слов (английские): {len(stopwords_english)}\n"
    f"Всего стоп-слов (русские):{len(stopwords_russian)}\n"
    f"Всего стоп-слов (объединенные):{len(common)}\n"
)
# Out:
# Всего стоп-слов (английские): 198
# Всего стоп-слов (русские):151
# Всего стоп-слов (объединенные):349

# %% [markdown]
# 10. Проведите анализ результатов: какие стоп-слова были удалены из исходного текста?
#
# - создайте список для сохранения отфильтрованных слов
# - для каждого слова исходного текста (`text`)
# - если данное слово было в списке стоп-слов
# - добавляем его в созданный список
#
# *Выведите на экран отфильтрованные слова (т.е. удаленные)*

# %%
dlt_words = []
for word in words:
    if word.lower() in common:
        dlt_words.append(word)

print("Удаленные стоп-слова:", dlt_words)
# Out:
# Удаленные стоп-слова: ['this', 'is', 'a', 'for', 'it', 'some', 'and', 'этот', 'как', 'так', 'и']
