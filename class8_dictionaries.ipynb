# %% [markdown]
# <a href="https://colab.research.google.com/github/lipchenko/lipchenko_HSE_student/blob/main/class8_dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
# Python dict -> JSON string
json_string = json.dumps(student)
# JSON string -> Python dict
python_dict = json.loads(json_string)

# %%
student = {
        "name": "Mike",
        "age": 22,
        "courses": ["Language", "Literature"],
        "grades": {"Language": 60, "Literature": 70}
    }

del student["courses"]

new_age = student.pop("age")
print(student)
print(new_age)

value1 = student["name"] = "Sasha"
value2 = student ["age"] = 24
value3 = student ["courses"] = ["Art", "Maths"]
value4 = student ["grades"] = [ 69,  78]
print(student)


del student["courses"]

new_age = student.pop("age")

print(student)

for key in student:
  print(key)
things = student.keys()
print(things)

for value in student:
  print(value)
things2 = student.values()
print(things2)

for value in student:
  print(value)
things2 = student.values()
print(things2)

super_students = dict(Alice = "math", Mike = "Literature", Sasha = "Art", Nadya = "Language" )

bad_students =  dict([("Mike", "Math"), ("Alice", "Literature"), ("Anton", "Art")])
# Out:
# {'name': 'Mike', 'grades': {'Language': 60, 'Literature': 70}}
# 22
# {'name': 'Sasha', 'grades': [69, 78], 'age': 24, 'courses': ['Art', 'Maths']}
# {'name': 'Sasha', 'grades': [69, 78]}
# name
# grades
# dict_keys(['name', 'grades'])

# %%
import json

# Открытие файла
with open('/content/data (1).json', 'r', encoding='utf-8') as f:
    config = json.load(f)
for key in config.keys():
    print(key)
for value in config ["departments"].values():
    print(value)
for item in config ["departments"].items():
    print(item)
config ["departments"]["dev"] = "David"
if "budget" in config:
    config["budget"] *= 1.1
print(departments)
print(config)
with open('data_update.json', 'w', encoding='utf-8') as f:
    json.dump(config, f, ensure_ascii=False, indent=2)
# Out:
# company
# departments
# budget
# ['Alice', 'Bob']
# ['Charlie']
# ('dev', ['Alice', 'Bob'])
# ('hr', ['Charlie'])
# {'dev': 'David', 'hr': ['Charlie']}
# {'company': 'TechCorp', 'departments': {'dev': 'David', 'hr': ['Charlie']}, 'budget': 110000.00000000001}
